# %%
# %pip install ipympl
# %pip install reportlab>=3.6.2
# %pip install PyPDF2
# %pip install ocrmypdf
# %pip install pdf2jpg
# %pip install PyMuPDF

# %%
from tempfile import TemporaryDirectory
import os
os.environ['USE_TORCH'] = '1'
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
from doctr.io import DocumentFile
from doctr.models import ocr_predictor
from PIL import Image
from PyPDF2 import PdfMerger
from ocrmypdf.hocrtransform import HocrTransform
import fitz

# %%
new_orig_pdf_path = Path('amendments/New_Exhibit_Redacted.pdf')
old_orig_pdf_path = Path('amendments/Old_Exhibit_Redacted.pdf')

det_arch_options  = ['linknet_resnet18',
                     'linknet_resnet34',
                     'linknet_resnet50',
                     'db_resnet50',
                     'db_mobilenet_v3_large',
                     'fast_tiny',
                     'fast_small',
                     'fast_base',]

reco_arch_options = ['crnn_vgg16_bn',
                     'crnn_mobilenet_v3_small',
                     'crnn_mobilenet_v3_large',
                     'sar_resnet31',
                     'master',
                     'vitstr_small',
                     'vitstr_base',
                     'parseq',]

predictor = ocr_predictor(det_arch='fast_base', reco_arch='crnn_vgg16_bn', pretrained=True)

# %%
def convert_pdf_page_to_image(fitz_doc, image_path, idx, zoom=4):
    mat = fitz.Matrix(zoom, zoom)
    page = fitz_doc.load_page(idx)
    pix = page.get_pixmap(matrix=mat)
    pix.save(image_path)

def write_ocr_text_to_pdfa(pdf_outpath, hocr_path, image_path):
    hocr = HocrTransform(hocr_filename=hocr_path,
                         dpi=1000,)

    # step to obtain ocirized pdf
    hocr.to_pdf(
                out_filename=pdf_outpath,
                image_filename=image_path,
                )
    
def write_hocr_xml_file(hocr_path, page_xml):
    with open(hocr_path, 'w') as f:
        f.write(page_xml[0].decode())

def create_pdfa_with_ocr(output_dir, output_stem, ocr_xml, fitz_doc):
    merger = PdfMerger()
    with TemporaryDirectory(dir= Path(os.getcwd())) as tmpdir:
        tmppath = Path(tmpdir)
        for idx, page_xml in enumerate(ocr_xml): 
            hocr_path   = tmppath / f'{output_stem}_hocr_page{idx}.xml'
            image_path  = tmppath / f'{output_stem}_image_page{idx}.png'
            pdf_outpath = tmppath / f'{output_stem}_docTR_page{idx}.pdf'
            write_hocr_xml_file(hocr_path, page_xml)
            convert_pdf_page_to_image(fitz_doc, image_path, idx, zoom=4) 
            write_ocr_text_to_pdfa(pdf_outpath, hocr_path, image_path)
            merger.append(pdf_outpath)
        merger.write(output_dir / f'{output_stem}_docTR.pdf' )
        merger.close()

# def write_ocr_text_to_pdfa(ocr_text, doc_pages, output_base_path):
#     # returns: list of tuple where the first element is the (bytes) xml string and the second is the ElementTree
#     xml_outputs = ocr_text.export_as_xml()

#     # init the above parser
#     parser = HocrParser()

#     merger = PdfMerger()
#     with TemporaryDirectory(dir= Path(os.getcwd())) as tmpdir:
#         tmppath = Path(tmpdir)
#         for i, (xml, img) in enumerate(zip(xml_outputs, doc_pages)):
#             xml_element_tree = xml[1]
#             pdf_file = str(tmppath / f'{i}.pdf')
#             parser.export_pdfa(pdf_file, hocr=xml_element_tree, image=img)
#             merger.append(pdf_file)
#         merger.write(f'{output_base_path}_docTR.pdf' )
#         merger.close()

# %%
for pdf_file in [old_orig_pdf_path, new_orig_pdf_path]:
    output_base_path = pdf_file.parent / pdf_file.stem
    doc_pages = DocumentFile.from_pdf(pdf_file)
    fitz_doc = fitz.open(pdf_file)
    ocr_text = predictor(doc_pages) 
    ocr_xml = ocr_text.export_as_xml()
    create_pdfa_with_ocr(output_dir  = pdf_file.parent, 
                         output_stem = pdf_file.stem, 
                         ocr_xml = ocr_xml, 
                         fitz_doc = fitz_doc)

# %%
ocr_dict = ocr_text.export()

# %%
for block in ocr_dict['pages'][0]['blocks']:
    for line in block['lines']:
        for word in line['words']:
            geo = word['geometry']
            text = word['value']
            print(f'left: {np.round(geo[0][0], 3)}, right: {np.round(geo[1][0], 3)}, top: {np.round(geo[0][1], 3)}, bottom: {np.round(geo[1][1], 3)}, {text}')
# Out:
# left: 0.47, right: 0.524, top: 0.065, bottom: 0.078, Exhibit
# left: 0.521, right: 0.553, top: 0.065, bottom: 0.079, A-4
# left: 0.369, right: 0.438, top: 0.133, bottom: 0.146, GROUND
# left: 0.438, right: 0.494, top: 0.133, bottom: 0.146, SPACE
# left: 0.492, right: 0.615, top: 0.133, bottom: 0.146, REQUIREMENTS
# left: 0.5, right: 0.542, top: 0.16, bottom: 0.174, 10.00'
# left: 0.5, right: 0.528, top: 0.175, bottom: 0.186, N/A
# left: 0.367, right: 0.436, top: 0.188, bottom: 0.202, BACKUP
# left: 0.434, right: 0.495, top: 0.188, bottom: 0.202, POWER
# left: 0.495, right: 0.618, top: 0.188, bottom: 0.202, REQUIREMENTS
# left: 0.494, right: 0.528, top: 0.201, bottom: 0.215, Fuel
# left: 0.525, right: 0.564, top: 0.202, bottom: 0.217, Type:
# left: 0.563, right: 0.591, top: 0.202, bottom: 0.214, N/A
# left: 0.419, right: 0.47, top: 0.216, bottom: 0.229, UTILITY
# left: 0.467, right: 0.563, top: 0.217, bottom: 0.227, REQUIREMENTS
# left: 0.035, right: 0.073, top: 0.146, bottom: 0.16, Total
# left: 0.069, right: 0.113, top: 0.146, bottom: 0.16, Lease
# left: 0.109, right: 0.146, top: 0.146, bottom: 0.161, Area
# left: 0.144, right: 0.185, top: 0.147, bottom: 0.161, Sq.Ft:
# left: 0.184, right: 0.231, top: 0.146, bottom: 0.16, 216.00
# left: 0.259, right: 0.313, top: 0.146, bottom: 0.161, Primary
# left: 0.31, right: 0.389, top: 0.147, bottom: 0.161, Contiguous
# left: 0.385, right: 0.43, top: 0.146, bottom: 0.16, Lease
# left: 0.425, right: 0.463, top: 0.146, bottom: 0.161, Area
# left: 0.479, right: 0.496, top: 0.147, bottom: 0.16, L:
# left: 0.501, right: 0.542, top: 0.146, bottom: 0.16, 12.00'
# left: 0.588, right: 0.61, top: 0.147, bottom: 0.159, W:
# left: 0.624, right: 0.666, top: 0.146, bottom: 0.16, 18.00'
# left: 0.695, right: 0.715, top: 0.147, bottom: 0.159, H:
# left: 0.724, right: 0.764, top: 0.146, bottom: 0.16, 10.00'
# left: 0.784, right: 0.826, top: 0.147, bottom: 0.161, Sq.Ft:
# left: 0.845, right: 0.891, top: 0.146, bottom: 0.16, 216.00
# left: 0.256, right: 0.315, top: 0.16, bottom: 0.174, Concrete
# left: 0.314, right: 0.341, top: 0.161, bottom: 0.173, Pad
# left: 0.256, right: 0.31, top: 0.174, bottom: 0.187, Outside
# left: 0.309, right: 0.364, top: 0.174, bottom: 0.188, Primary
# left: 0.36, right: 0.405, top: 0.174, bottom: 0.188, Lease
# left: 0.401, right: 0.437, top: 0.174, bottom: 0.188, Area
# left: 0.274, right: 0.308, top: 0.201, bottom: 0.215, Fuel
# left: 0.305, right: 0.343, top: 0.201, bottom: 0.215, Tank
# left: 0.339, right: 0.372, top: 0.201, bottom: 0.215, Size
# left: 0.37, right: 0.406, top: 0.202, bottom: 0.217, (gal):
# left: 0.406, right: 0.433, top: 0.202, bottom: 0.214, N/A
# left: 0.624, right: 0.666, top: 0.16, bottom: 0.174, 16.00'
# left: 0.625, right: 0.65, top: 0.175, bottom: 0.187, N/A
# left: 0.724, right: 0.75, top: 0.161, bottom: 0.173, N/A
# left: 0.724, right: 0.75, top: 0.175, bottom: 0.187, N/A
# left: 0.784, right: 0.826, top: 0.174, bottom: 0.188, Sq.Ft:
# left: 0.845, right: 0.873, top: 0.174, bottom: 0.186, N/A
# left: 0.722, right: 0.755, top: 0.201, bottom: 0.215, Fuel
# left: 0.753, right: 0.791, top: 0.201, bottom: 0.215, Tank
# left: 0.787, right: 0.844, top: 0.201, bottom: 0.215, Setback
# left: 0.841, right: 0.899, top: 0.202, bottom: 0.216, (radius):
# left: 0.897, right: 0.925, top: 0.202, bottom: 0.214, N/A
# left: 0.845, right: 0.891, top: 0.159, bottom: 0.174, 160.00
# left: 0.043, right: 0.115, top: 0.202, bottom: 0.215, Generator:
# left: 0.113, right: 0.14, top: 0.202, bottom: 0.214, N/A
# left: 0.043, right: 0.088, top: 0.229, bottom: 0.242, Power
# left: 0.085, right: 0.146, top: 0.229, bottom: 0.242, Provided
# left: 0.145, right: 0.171, top: 0.229, bottom: 0.244, By:
# left: 0.169, right: 0.207, top: 0.229, bottom: 0.243, Utility
# left: 0.206, right: 0.266, top: 0.229, bottom: 0.243, Company
# left: 0.265, right: 0.305, top: 0.229, bottom: 0.242, Direct
# left: 0.044, right: 0.166, top: 0.243, bottom: 0.253, Telco/interconnect:
# left: 0.166, right: 0.194, top: 0.242, bottom: 0.254, N/A
# left: 0.041, right: 0.083, top: 0.269, bottom: 0.283, Type:
# left: 0.08, right: 0.109, top: 0.268, bottom: 0.282, N/A
# left: 0.041, right: 0.078, top: 0.3, bottom: 0.314, Type
# left: 0.043, right: 0.131, top: 0.317, bottom: 0.33, Manufacturer
# left: 0.043, right: 0.085, top: 0.338, bottom: 0.352, Model
# left: 0.083, right: 0.097, top: 0.338, bottom: 0.351, #
# left: 0.043, right: 0.122, top: 0.356, bottom: 0.369, Dimensions
# left: 0.043, right: 0.094, top: 0.368, bottom: 0.381, HxWxD
# left: 0.043, right: 0.092, top: 0.384, bottom: 0.397, Weight
# left: 0.089, right: 0.126, top: 0.384, bottom: 0.398, (Ibs.)
# left: 0.043, right: 0.102, top: 0.4, bottom: 0.413, Location
# left: 0.043, right: 0.077, top: 0.418, bottom: 0.432, RAD
# left: 0.074, right: 0.122, top: 0.418, bottom: 0.432, Center
# left: 0.118, right: 0.154, top: 0.418, bottom: 0.432, AGL
# left: 0.041, right: 0.068, top: 0.435, bottom: 0.45, Tip
# left: 0.065, right: 0.112, top: 0.436, bottom: 0.45, Height
# left: 0.043, right: 0.079, top: 0.452, bottom: 0.466, Base
# left: 0.078, right: 0.123, top: 0.452, bottom: 0.467, Height
# left: 0.043, right: 0.088, top: 0.47, bottom: 0.483, Mount
# left: 0.085, right: 0.121, top: 0.47, bottom: 0.485, Type
# left: 0.043, right: 0.101, top: 0.487, bottom: 0.502, Quantity
# left: 0.043, right: 0.131, top: 0.502, bottom: 0.515, Azimuths/Dir.
# left: 0.131, right: 0.149, top: 0.503, bottom: 0.515, of
# left: 0.043, right: 0.108, top: 0.514, bottom: 0.527, Radiation
# left: 0.044, right: 0.089, top: 0.528, bottom: 0.54, Quant.
# left: 0.088, right: 0.113, top: 0.527, bottom: 0.539, Per
# left: 0.041, right: 0.145, top: 0.539, bottom: 0.552, Azimuth/Sector
# left: 0.041, right: 0.087, top: 0.551, bottom: 0.564, TX/RX
# left: 0.085, right: 0.155, top: 0.552, bottom: 0.565, Frequency
# left: 0.043, right: 0.079, top: 0.564, bottom: 0.575, Units
# left: 0.041, right: 0.064, top: 0.582, bottom: 0.594, TX
# left: 0.064, right: 0.134, top: 0.582, bottom: 0.597, Frequency
# left: 0.041, right: 0.068, top: 0.604, bottom: 0.619, RXI
# left: 0.065, right: 0.135, top: 0.606, bottom: 0.62, Frequency
# left: 0.043, right: 0.084, top: 0.624, bottom: 0.639, Using
# left: 0.083, right: 0.158, top: 0.624, bottom: 0.637, Unlicensed
# left: 0.043, right: 0.132, top: 0.637, bottom: 0.65, Frequencies?
# left: 0.043, right: 0.101, top: 0.651, bottom: 0.664, Antenna
# left: 0.099, right: 0.132, top: 0.652, bottom: 0.663, Gain
# left: 0.041, right: 0.079, top: 0.668, bottom: 0.682, Total
# left: 0.077, right: 0.091, top: 0.668, bottom: 0.681, #
# left: 0.089, right: 0.107, top: 0.669, bottom: 0.681, of
# left: 0.104, right: 0.144, top: 0.668, bottom: 0.682, Lines
# left: 0.043, right: 0.108, top: 0.707, bottom: 0.72, Individual
# left: 0.107, right: 0.14, top: 0.707, bottom: 0.721, Line
# left: 0.044, right: 0.132, top: 0.72, bottom: 0.733, Configuration
# left: 0.345, right: 0.443, top: 0.256, bottom: 0.269, TRANSMITTER
# left: 0.442, right: 0.457, top: 0.255, bottom: 0.269, &
# left: 0.455, right: 0.528, top: 0.256, bottom: 0.269, RECEIVER:
# left: 0.527, right: 0.639, top: 0.257, bottom: 0.267, SPECIFICATIONS
# left: 0.449, right: 0.471, top: 0.269, bottom: 0.281, TX
# left: 0.468, right: 0.515, top: 0.269, bottom: 0.282, Power
# left: 0.513, right: 0.563, top: 0.269, bottom: 0.283, (watts):
# left: 0.561, right: 0.591, top: 0.268, bottom: 0.282, N/A
# left: 0.406, right: 0.48, top: 0.282, bottom: 0.295, EQUIPMENT
# left: 0.477, right: 0.58, top: 0.282, bottom: 0.295, SPECIFICATIONS
# left: 0.468, right: 0.516, top: 0.3, bottom: 0.313, PANEL
# left: 0.467, right: 0.52, top: 0.317, bottom: 0.33, CellMax
# left: 0.251, right: 0.313, top: 0.269, bottom: 0.283, Quantity:
# left: 0.31, right: 0.341, top: 0.268, bottom: 0.282, N/A
# left: 0.214, right: 0.249, top: 0.3, bottom: 0.313, GPS
# left: 0.206, right: 0.259, top: 0.317, bottom: 0.33, Generic
# left: 0.216, right: 0.25, top: 0.338, bottom: 0.352, GPS
# left: 0.194, right: 0.27, top: 0.362, bottom: 0.375, 12"x9"x6"
# left: 0.217, right: 0.249, top: 0.384, bottom: 0.397, 10.0
# left: 0.208, right: 0.256, top: 0.4, bottom: 0.413, Ground
# left: 0.218, right: 0.247, top: 0.417, bottom: 0.432, N/A
# left: 0.219, right: 0.245, top: 0.436, bottom: 0.447, N/A
# left: 0.219, right: 0.245, top: 0.453, bottom: 0.465, N/A
# left: 0.219, right: 0.245, top: 0.471, bottom: 0.482, N/A
# left: 0.226, right: 0.238, top: 0.487, bottom: 0.5, 1
# left: 0.219, right: 0.245, top: 0.509, bottom: 0.521, N/A
# left: 0.219, right: 0.246, top: 0.533, bottom: 0.545, N/A
# left: 0.219, right: 0.245, top: 0.558, bottom: 0.569, N/A
# left: 0.219, right: 0.245, top: 0.582, bottom: 0.594, N/A
# left: 0.219, right: 0.245, top: 0.606, bottom: 0.618, N/A
# left: 0.222, right: 0.242, top: 0.631, bottom: 0.642, No
# left: 0.217, right: 0.246, top: 0.65, bottom: 0.665, N/A
# left: 0.219, right: 0.245, top: 0.669, bottom: 0.681, N/A
# left: 0.17, right: 0.195, top: 0.686, bottom: 0.697, N/A
# left: 0.722, right: 0.757, top: 0.269, bottom: 0.282, ERP
# left: 0.753, right: 0.8, top: 0.268, bottom: 0.282, Power
# left: 0.796, right: 0.849, top: 0.269, bottom: 0.283, (watts):
# left: 0.846, right: 0.875, top: 0.268, bottom: 0.282, N/A
# left: 0.722, right: 0.786, top: 0.302, bottom: 0.312, RRU/RRH
# left: 0.726, right: 0.782, top: 0.317, bottom: 0.33, Ericsson
# left: 0.338, right: 0.386, top: 0.3, bottom: 0.313, PANEL
# left: 0.346, right: 0.379, top: 0.316, bottom: 0.33, RFS
# left: 0.305, right: 0.419, top: 0.332, bottom: 0.346, APXVAA24.43-U-
# left: 0.347, right: 0.377, top: 0.343, bottom: 0.357, A20
# left: 0.345, right: 0.381, top: 0.385, bottom: 0.396, 101.4
# left: 0.341, right: 0.384, top: 0.4, bottom: 0.414, Tower
# left: 0.342, right: 0.384, top: 0.417, bottom: 0.431, 180.0'
# left: 0.342, right: 0.384, top: 0.435, bottom: 0.448, 184.0'
# left: 0.342, right: 0.384, top: 0.452, bottom: 0.466, 176.0'
# left: 0.332, right: 0.365, top: 0.47, bottom: 0.483, Side
# left: 0.361, right: 0.393, top: 0.47, bottom: 0.483, Arm
# left: 0.356, right: 0.37, top: 0.486, bottom: 0.5, 3
# left: 0.328, right: 0.396, top: 0.51, bottom: 0.52, 60/180/300
# left: 0.345, right: 0.379, top: 0.532, bottom: 0.546, 1/1/1
# left: 0.346, right: 0.38, top: 0.557, bottom: 0.57, MHz
# left: 0.334, right: 0.388, top: 0.582, bottom: 0.595, 668-688
# left: 0.333, right: 0.388, top: 0.606, bottom: 0.619, 622-642
# left: 0.352, right: 0.374, top: 0.631, bottom: 0.642, No
# left: 0.328, right: 0.367, top: 0.652, bottom: 0.663, 13.2/1
# left: 0.364, right: 0.395, top: 0.651, bottom: 0.665, 13.6
# left: 0.356, right: 0.37, top: 0.668, bottom: 0.682, 3
# left: 0.299, right: 0.328, top: 0.685, bottom: 0.699, Qty:
# left: 0.327, right: 0.341, top: 0.685, bottom: 0.697, 3
# left: 0.299, right: 0.338, top: 0.695, bottom: 0.711, Type:
# left: 0.336, right: 0.372, top: 0.695, bottom: 0.709, Coax
# left: 0.299, right: 0.396, top: 0.72, bottom: 0.732, Azimuth/Sector:
# left: 0.395, right: 0.43, top: 0.719, bottom: 0.732, 1/1/1
# left: 0.429, right: 0.467, top: 0.719, bottom: 0.732, Coax
# left: 0.3, right: 0.326, top: 0.758, bottom: 0.769, N/A
# left: 0.607, right: 0.639, top: 0.3, bottom: 0.314, TTA
# left: 0.607, right: 0.64, top: 0.316, bottom: 0.33, RFS
# left: 0.854, right: 0.916, top: 0.302, bottom: 0.312, RRU/RRH
# left: 0.856, right: 0.913, top: 0.317, bottom: 0.33, Ericsson
# left: 0.86, right: 0.908, top: 0.338, bottom: 0.351, RRU22
# left: 0.868, right: 0.901, top: 0.383, bottom: 0.396, 52.9
# left: 0.864, right: 0.906, top: 0.401, bottom: 0.412, Tower
# left: 0.864, right: 0.906, top: 0.417, bottom: 0.431, 180.0'
# left: 0.865, right: 0.906, top: 0.435, bottom: 0.448, 180.8'
# left: 0.864, right: 0.906, top: 0.452, bottom: 0.466, 179.2'
# left: 0.854, right: 0.887, top: 0.47, bottom: 0.483, Side
# left: 0.883, right: 0.915, top: 0.47, bottom: 0.483, Arm
# left: 0.878, right: 0.892, top: 0.487, bottom: 0.5, 1
# left: 0.875, right: 0.893, top: 0.509, bottom: 0.521, 60
# left: 0.878, right: 0.891, top: 0.532, bottom: 0.545, 1
# left: 0.868, right: 0.902, top: 0.557, bottom: 0.57, MHz
# left: 0.832, right: 0.936, top: 0.576, bottom: 0.59, 2145-2155,1735-
# left: 0.868, right: 0.902, top: 0.587, bottom: 0.601, 1740
# left: 0.832, right: 0.937, top: 0.601, bottom: 0.613, 1745-1755,2135-
# left: 0.866, right: 0.902, top: 0.611, bottom: 0.625, 2140
# left: 0.874, right: 0.896, top: 0.631, bottom: 0.642, No
# left: 0.87, right: 0.899, top: 0.65, bottom: 0.665, N/A
# left: 0.878, right: 0.892, top: 0.668, bottom: 0.682, 2
# left: 0.822, right: 0.849, top: 0.686, bottom: 0.697, N/A
# left: 0.439, right: 0.548, top: 0.34, bottom: 0.35, CMA-B/6521/E0-6
# left: 0.567, right: 0.681, top: 0.338, bottom: 0.351, ATM1900D-1CWA
# left: 0.705, right: 0.745, top: 0.338, bottom: 0.352, Radio
# left: 0.741, right: 0.777, top: 0.338, bottom: 0.352, 4478
# left: 0.777, right: 0.802, top: 0.339, bottom: 0.351, B71
# left: 0.317, right: 0.339, top: 0.362, bottom: 0.374, 96"
# left: 0.336, right: 0.351, top: 0.363, bottom: 0.376, x
# left: 0.347, right: 0.374, top: 0.361, bottom: 0.376, 24"
# left: 0.37, right: 0.384, top: 0.363, bottom: 0.375, x
# left: 0.381, right: 0.412, top: 0.361, bottom: 0.376, 8.5"
# left: 0.438, right: 0.511, top: 0.362, bottom: 0.375, 81.1"x7.7":
# left: 0.508, right: 0.523, top: 0.363, bottom: 0.375, X4
# left: 0.518, right: 0.549, top: 0.361, bottom: 0.376, 4.8"
# left: 0.576, right: 0.602, top: 0.362, bottom: 0.374, 8.6"
# left: 0.6, right: 0.614, top: 0.362, bottom: 0.375, x
# left: 0.612, right: 0.635, top: 0.362, bottom: 0.375, 10"
# left: 0.633, right: 0.647, top: 0.363, bottom: 0.375, x
# left: 0.644, right: 0.674, top: 0.361, bottom: 0.376, 2.6"
# left: 0.702, right: 0.726, top: 0.363, bottom: 0.374, 15"
# left: 0.724, right: 0.738, top: 0.363, bottom: 0.375, x
# left: 0.734, right: 0.772, top: 0.361, bottom: 0.375, 13.2"
# left: 0.764, right: 0.807, top: 0.361, bottom: 0.376, x7.4"
# left: 0.826, right: 0.864, top: 0.361, bottom: 0.375, 20.2"
# left: 0.859, right: 0.873, top: 0.362, bottom: 0.375, x
# left: 0.87, right: 0.907, top: 0.361, bottom: 0.375, 13.2"
# left: 0.902, right: 0.918, top: 0.362, bottom: 0.374, x6
# left: 0.915, right: 0.942, top: 0.362, bottom: 0.374, 6.9"
# left: 0.477, right: 0.509, top: 0.383, bottom: 0.397, 35.0
# left: 0.471, right: 0.515, top: 0.4, bottom: 0.414, Tower
# left: 0.472, right: 0.514, top: 0.417, bottom: 0.431, 180.0'
# left: 0.473, right: 0.514, top: 0.435, bottom: 0.448, 183.4'
# left: 0.473, right: 0.514, top: 0.452, bottom: 0.466, 176.6'
# left: 0.463, right: 0.496, top: 0.47, bottom: 0.483, Side
# left: 0.491, right: 0.523, top: 0.47, bottom: 0.483, Arm
# left: 0.486, right: 0.5, top: 0.487, bottom: 0.5, 6
# left: 0.461, right: 0.524, top: 0.508, bottom: 0.521, 60/80/300
# left: 0.475, right: 0.511, top: 0.532, bottom: 0.546, 2/2/2
# left: 0.476, right: 0.51, top: 0.557, bottom: 0.57, MHz
# left: 0.442, right: 0.545, top: 0.576, bottom: 0.589, 1930-1945,2145-
# left: 0.443, right: 0.543, top: 0.588, bottom: 0.601, 2155,1735-1740
# left: 0.442, right: 0.545, top: 0.601, bottom: 0.613, 1850-1865,1745-
# left: 0.443, right: 0.543, top: 0.611, bottom: 0.625, 1755,2135-2140
# left: 0.482, right: 0.504, top: 0.631, bottom: 0.642, No
# left: 0.444, right: 0.481, top: 0.651, bottom: 0.665, 18.3/
# left: 0.479, right: 0.511, top: 0.652, bottom: 0.663, 18.7/
# left: 0.51, right: 0.542, top: 0.651, bottom: 0.665, 19.2
# left: 0.486, right: 0.5, top: 0.668, bottom: 0.682, 6
# left: 0.429, right: 0.46, top: 0.685, bottom: 0.699, Qty:
# left: 0.457, right: 0.471, top: 0.685, bottom: 0.698, 6
# left: 0.429, right: 0.468, top: 0.695, bottom: 0.711, Type:
# left: 0.466, right: 0.503, top: 0.695, bottom: 0.71, Coax
# left: 0.43, right: 0.457, top: 0.758, bottom: 0.77, N/A
# left: 0.612, right: 0.635, top: 0.384, bottom: 0.396, 8.4
# left: 0.602, right: 0.645, top: 0.4, bottom: 0.414, Tower
# left: 0.604, right: 0.644, top: 0.417, bottom: 0.431, 180.0'
# left: 0.604, right: 0.644, top: 0.435, bottom: 0.448, 180.4'
# left: 0.604, right: 0.644, top: 0.452, bottom: 0.466, 179.6'
# left: 0.594, right: 0.626, top: 0.47, bottom: 0.483, Side
# left: 0.623, right: 0.654, top: 0.47, bottom: 0.483, Arm
# left: 0.616, right: 0.63, top: 0.487, bottom: 0.5, 3
# left: 0.588, right: 0.659, top: 0.508, bottom: 0.521, 60/180/300
# left: 0.606, right: 0.64, top: 0.532, bottom: 0.546, 1/1/1
# left: 0.61, right: 0.636, top: 0.558, bottom: 0.569, N/A
# left: 0.61, right: 0.636, top: 0.582, bottom: 0.594, N/A
# left: 0.61, right: 0.636, top: 0.606, bottom: 0.618, N/A
# left: 0.612, right: 0.634, top: 0.631, bottom: 0.642, No
# left: 0.615, right: 0.634, top: 0.652, bottom: 0.663, 12
# left: 0.618, right: 0.63, top: 0.668, bottom: 0.682, 1
# left: 0.559, right: 0.59, top: 0.685, bottom: 0.699, Qty:
# left: 0.588, right: 0.601, top: 0.685, bottom: 0.698, 1
# left: 0.739, right: 0.769, top: 0.385, bottom: 0.396, 60.0
# left: 0.733, right: 0.776, top: 0.4, bottom: 0.414, Tower
# left: 0.734, right: 0.774, top: 0.417, bottom: 0.431, 180.0'
# left: 0.734, right: 0.776, top: 0.435, bottom: 0.448, 180.6'
# left: 0.734, right: 0.776, top: 0.452, bottom: 0.466, 179.4'
# left: 0.724, right: 0.757, top: 0.47, bottom: 0.483, Side
# left: 0.753, right: 0.784, top: 0.47, bottom: 0.483, Arm
# left: 0.748, right: 0.76, top: 0.486, bottom: 0.5, 3
# left: 0.719, right: 0.789, top: 0.508, bottom: 0.521, 60/180/300
# left: 0.736, right: 0.77, top: 0.532, bottom: 0.546, 1/1/1
# left: 0.741, right: 0.768, top: 0.558, bottom: 0.569, N/A
# left: 0.74, right: 0.769, top: 0.581, bottom: 0.596, N/A
# left: 0.741, right: 0.768, top: 0.606, bottom: 0.618, N/A
# left: 0.744, right: 0.764, top: 0.631, bottom: 0.642, No
# left: 0.74, right: 0.769, top: 0.65, bottom: 0.665, N/A
# left: 0.748, right: 0.76, top: 0.668, bottom: 0.682, 3
# left: 0.69, right: 0.72, top: 0.685, bottom: 0.7, Qty:
# left: 0.717, right: 0.731, top: 0.685, bottom: 0.697, 3
# left: 0.559, right: 0.599, top: 0.695, bottom: 0.711, Type:
# left: 0.597, right: 0.672, top: 0.696, bottom: 0.711, Fiber/Hybrid
# left: 0.691, right: 0.729, top: 0.695, bottom: 0.711, Type:
# left: 0.726, right: 0.764, top: 0.695, bottom: 0.709, Coax
# left: 0.561, right: 0.655, top: 0.72, bottom: 0.733, (1.63'-41.3mm)
# left: 0.654, right: 0.691, top: 0.719, bottom: 0.732, Fiber
# left: 0.691, right: 0.788, top: 0.719, bottom: 0.732, Azimuth/Sector:
# left: 0.787, right: 0.821, top: 0.719, bottom: 0.733, 1/1/1
# left: 0.299, right: 0.361, top: 0.708, bottom: 0.721, Diameter:
# left: 0.361, right: 0.388, top: 0.709, bottom: 0.721, 1/2"
# left: 0.385, right: 0.423, top: 0.708, bottom: 0.722, Coax
# left: 0.429, right: 0.492, top: 0.708, bottom: 0.721, Diameter:
# left: 0.49, right: 0.503, top: 0.707, bottom: 0.721, 1
# left: 0.501, right: 0.529, top: 0.709, bottom: 0.721, 5/8"
# left: 0.561, right: 0.623, top: 0.708, bottom: 0.722, Diameter:
# left: 0.62, right: 0.634, top: 0.708, bottom: 0.721, 1
# left: 0.631, right: 0.661, top: 0.707, bottom: 0.722, 5/8"
# left: 0.691, right: 0.753, top: 0.708, bottom: 0.721, Diameter:
# left: 0.753, right: 0.779, top: 0.709, bottom: 0.721, 1/4"
# left: 0.777, right: 0.815, top: 0.707, bottom: 0.722, Coax
# left: 0.429, right: 0.528, top: 0.731, bottom: 0.744, Azimuth/Sector:
# left: 0.525, right: 0.562, top: 0.73, bottom: 0.745, 2/2/2
# left: 0.559, right: 0.658, top: 0.731, bottom: 0.744, Azimuth/Sector:
# left: 0.655, right: 0.691, top: 0.731, bottom: 0.745, 1/0/0
# left: 0.17, right: 0.195, top: 0.757, bottom: 0.769, N/A
# left: 0.559, right: 0.588, top: 0.756, bottom: 0.771, N/A
# left: 0.69, right: 0.719, top: 0.756, bottom: 0.771, NIA
# left: 0.821, right: 0.851, top: 0.757, bottom: 0.771, Qty:
# left: 0.849, right: 0.861, top: 0.757, bottom: 0.771, 1
# left: 0.821, right: 0.859, top: 0.769, bottom: 0.783, Type:
# left: 0.858, right: 0.875, top: 0.769, bottom: 0.781, 2"
# left: 0.873, right: 0.922, top: 0.769, bottom: 0.782, conduit
# left: 0.821, right: 0.889, top: 0.78, bottom: 0.795, containing:
# left: 0.821, right: 0.835, top: 0.793, bottom: 0.807, -
# left: 0.821, right: 0.918, top: 0.804, bottom: 0.816, Azimuth/Sector:
# left: 0.917, right: 0.93, top: 0.803, bottom: 0.816, 1
# left: 0.821, right: 0.851, top: 0.839, bottom: 0.854, Qty:
# left: 0.849, right: 0.861, top: 0.839, bottom: 0.853, 1
# left: 0.821, right: 0.859, top: 0.85, bottom: 0.864, Type:
# left: 0.858, right: 0.874, top: 0.85, bottom: 0.863, 2"
# left: 0.873, right: 0.921, top: 0.85, bottom: 0.863, conduit
# left: 0.821, right: 0.889, top: 0.862, bottom: 0.877, containing:
# left: 0.821, right: 0.835, top: 0.875, bottom: 0.888, -
# left: 0.821, right: 0.918, top: 0.886, bottom: 0.898, Azimuth/Sector:
# left: 0.917, right: 0.93, top: 0.885, bottom: 0.898, 1
# left: 0.043, right: 0.098, top: 0.82, bottom: 0.833, Conduit
# left: 0.044, right: 0.132, top: 0.833, bottom: 0.847, Configuration

# %%
ocr_dict['pages'][0]['dimensions']
# Out:
# (1584, 1224)
